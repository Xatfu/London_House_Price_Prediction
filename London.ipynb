# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('/kaggle/London/train.csv')
df_test = pd.read_csv('/kaggle/London/test.csv')
df_sub = pd.read_csv('/kaggle/London/sample_submission.csv')

# %%
df_train.isna().sum()
# Out:
# ID                         0
# fullAddress                0
# postcode                   0
# country                    0
# outcode                    0
# latitude                   0
# longitude                  0
# bathrooms              48479
# bedrooms               24843
# floorAreaSqM           13806
# livingRooms            37040
# tenure                  5721
# propertyType             508
# currentEnergyRating    56814
# sale_month                 0
# sale_year                  0
# price                      0
# dtype: int64

# %%
df_train = df_train.drop(['ID', 'fullAddress', 'country', 'postcode'], axis = 1)
df_test = df_test.drop(['ID', 'fullAddress', 'country', 'postcode'], axis = 1)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266325 entries, 0 to 266324
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   outcode              266325 non-null  object
#  1   latitude             266325 non-null  float64
#  2   longitude            266325 non-null  float64
#  3   bathrooms            217846 non-null  float64
#  4   bedrooms             241482 non-null  float64
#  5   floorAreaSqM         252519 non-null  float64
#  6   livingRooms          229285 non-null  float64
#  7   tenure               260604 non-null  object
#  8   propertyType         265817 non-null  object
#  9   currentEnergyRating  209511 non-null  object
#  10  sale_month           266325 non-null  int64
#  11  sale_year            266325 non-null  int64
#  12  price                266325 non-null  int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 26.4+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16547 entries, 0 to 16546
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   outcode              16547 non-null  object
#  1   latitude             16547 non-null  float64
#  2   longitude            16547 non-null  float64
#  3   bathrooms            13923 non-null  float64
#  4   bedrooms             15172 non-null  float64
#  5   floorAreaSqM         14541 non-null  float64
#  6   livingRooms          14452 non-null  float64
#  7   tenure               15957 non-null  object
#  8   propertyType         16380 non-null  object
#  9   currentEnergyRating  15050 non-null  object
#  10  sale_month           16547 non-null  int64
#  11  sale_year            16547 non-null  int64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 1.5+ MB

# %%
df_test.isna().sum()
# Out:
# outcode                   0
# latitude                  0
# longitude                 0
# bathrooms              2624
# bedrooms               1375
# floorAreaSqM           2006
# livingRooms            2095
# tenure                  590
# propertyType            167
# currentEnergyRating    1497
# sale_month                0
# sale_year                 0
# dtype: int64

# %%
df_train.isna().sum()
# Out:
# outcode                    0
# latitude                   0
# longitude                  0
# bathrooms              48479
# bedrooms               24843
# floorAreaSqM           13806
# livingRooms            37040
# tenure                  5721
# propertyType             508
# currentEnergyRating    56814
# sale_month                 0
# sale_year                  0
# price                      0
# dtype: int64

# %%
df_train['bathrooms'].value_counts()
# Out:
# bathrooms
# 1.0    143432
# 2.0     58789
# 3.0     11786
# 4.0      2662
# 5.0       706
# 6.0       321
# 7.0       103
# 8.0        33
# 9.0        14
# Name: count, dtype: int64

# %%
df_test['bathrooms'].value_counts()
# Out:
# bathrooms
# 1.0    8959
# 2.0    3944
# 3.0     761
# 4.0     170
# 5.0      57
# 6.0      23
# 7.0       5
# 8.0       3
# 9.0       1
# Name: count, dtype: int64

# %%
df_train.loc[df_train['bathrooms'].isna(), 'bathrooms'] = np.random.choice(a = [1.0, 2.0, 3.0, 4.0], size = df_train['bathrooms'].isna().sum(), p = [0.5, 0.3, 0.1, 0.1])
df_test.loc[df_test['bathrooms'].isna(), 'bathrooms'] = np.random.choice(a = [1.0, 2.0, 3.0, 4.0], size = df_test['bathrooms'].isna().sum(), p = [0.5, 0.3, 0.1, 0.1])

# %%
df_train['bedrooms'].value_counts()
# Out:
# bedrooms
# 2.0    90652
# 3.0    61396
# 1.0    46794
# 4.0    27638
# 5.0    11222
# 6.0     2940
# 7.0      595
# 8.0      185
# 9.0       60
# Name: count, dtype: int64

# %%
df_test['bedrooms'].value_counts()
# Out:
# bedrooms
# 2.0    5562
# 3.0    3996
# 1.0    2863
# 4.0    1803
# 5.0     686
# 6.0     194
# 7.0      50
# 8.0      13
# 9.0       5
# Name: count, dtype: int64

# %%
df_train.loc[df_train['bedrooms'].isna(), 'bedrooms'] = np.random.choice(a = [2.0, 3.0, 1.0, 4.0], size = df_train['bedrooms'].isna().sum(), p = [0.5, 0.3, 0.1, 0.1])
df_test.loc[df_test['bedrooms'].isna(), 'bedrooms'] = np.random.choice(a = [2.0, 3.0, 1.0, 4.0], size = df_test['bedrooms'].isna().sum(), p = [0.5, 0.3, 0.1, 0.1])

# %%
df_train['floorAreaSqM'].value_counts()
# Out:
# floorAreaSqM
# 55.0     4477
# 70.0     3911
# 56.0     3761
# 80.0     3512
# 54.0     3454
#          ...
# 490.0       2
# 469.0       1
# 421.0       1
# 442.0       1
# 441.0       1
# Name: count, Length: 488, dtype: int64

# %%
df_test['floorAreaSqM'].value_counts()
# Out:
# floorAreaSqM
# 55.0     286
# 70.0     238
# 54.0     220
# 56.0     218
# 80.0     209
#         ...
# 308.0      1
# 448.0      1
# 403.0      1
# 10.0       1
# 323.0      1
# Name: count, Length: 385, dtype: int64

# %%
df_test['floorAreaSqM'].value_counts()
# Out:
# floorAreaSqM
# 55.0     286
# 70.0     238
# 54.0     220
# 56.0     218
# 80.0     209
#         ...
# 308.0      1
# 448.0      1
# 403.0      1
# 10.0       1
# 323.0      1
# Name: count, Length: 385, dtype: int64

# %%
df_train['floorAreaSqM'].value_counts()
# Out:
# floorAreaSqM
# 55.0     4477
# 70.0     3911
# 56.0     3761
# 80.0     3512
# 54.0     3454
#          ...
# 490.0       2
# 469.0       1
# 421.0       1
# 442.0       1
# 441.0       1
# Name: count, Length: 488, dtype: int64

# %%
len(df_train['floorAreaSqM'])
# Out:
# 266325

# %%
df_train['livingRooms'].value_counts()
# Out:
# livingRooms
# 1.0    174397
# 2.0     45182
# 3.0      7891
# 4.0      1380
# 5.0       328
# 6.0        76
# 7.0        26
# 8.0         4
# 9.0         1
# Name: count, dtype: int64

# %%
len(df_train['livingRooms'])
# Out:
# 266325

# %%
df_test.isna().sum()
# Out:
# outcode                   0
# latitude                  0
# longitude                 0
# bathrooms                 0
# bedrooms                  0
# floorAreaSqM           2006
# livingRooms            2095
# tenure                  590
# propertyType            167
# currentEnergyRating    1497
# sale_month                0
# sale_year                 0
# dtype: int64

# %%
df_train.isna().sum()
# Out:
# outcode                    0
# latitude                   0
# longitude                  0
# bathrooms                  0
# bedrooms                   0
# floorAreaSqM           13806
# livingRooms            37040
# tenure                  5721
# propertyType             508
# currentEnergyRating    56814
# sale_month                 0
# sale_year                  0
# price                      0
# dtype: int64

# %%
df_train['rooms_is_missing'] = df_train['livingRooms'].isna().astype(int)
df_train['area_is_missing'] = df_train['floorAreaSqM'].isna().astype(int)

# %%
df_train['livingRooms'] = df_train['livingRooms'].fillna(1.0)

df_train['floorAreaSqM'] = df_train['floorAreaSqM'].fillna(df_train.groupby('livingRooms')['floorAreaSqM'].transform('median'))

# %%
df_test['rooms_is_missing'] = df_test['livingRooms'].isna().astype(int)
df_test['area_is_missing'] = df_test['floorAreaSqM'].isna().astype(int)

# %%
df_test['livingRooms'] = df_test['livingRooms'].fillna(1.0)

# %%
df_test['floorAreaSqM'] = df_test['floorAreaSqM'].fillna(df_test.groupby('livingRooms')['floorAreaSqM'].transform('median'))

# %%
print(df_train[df_train['floorAreaSqM'].isna()]['livingRooms'])
# Out:
# 4925      8.0
# 19711     8.0
# 43856     8.0
# 182691    9.0
# 258245    8.0
# Name: livingRooms, dtype: float64

# %%
df_train['floorAreaSqM'] = df_train['floorAreaSqM'].fillna(df_train['floorAreaSqM'].median())

# %%
df_train['propertyType'].value_counts()
# Out:
# propertyType
# Purpose Built Flat        68726
# Flat/Maisonette           61139
# Mid Terrace House         45649
# Converted Flat            32552
# Semi-Detached House       20475
# Terrace Property          15114
# End Terrace House         13063
# Detached House             6666
# Terraced                    927
# Bungalow Property           267
# Semi-Detached Property      254
# Semi-Detached Bungalow      232
# Detached Bungalow           186
# Detached Property           160
# End Terrace Property        149
# Mid Terrace Property        120
# Mid Terrace Bungalow         67
# Terraced Bungalow            38
# End Terrace Bungalow         33
# Name: count, dtype: int64

# %%
len(df_train['tenure'])
# Out:
# 266325

# %%
df_test['tenure'].value_counts()
# Out:
# tenure
# Leasehold    9017
# Freehold     6643
# Feudal        229
# Shared         68
# Name: count, dtype: int64

# %%
df_train.loc[df_train['tenure'].isna(), 'tenure'] = np.random.choice(a = ['Leasehold', 'Freehold'], size = df_train['tenure'].isna().sum(), p = [0.7, 0.3])
df_test.loc[df_test['tenure'].isna(), 'tenure'] = np.random.choice(a = ['Leasehold', 'Freehold'], size = df_test['tenure'].isna().sum(), p = [0.7, 0.3])

# %%
df_train['tenure'].value_counts()
# Out:
# tenure
# Leasehold    159880
# Freehold     103847
# Feudal         1906
# Shared          692
# Name: count, dtype: int64

# %%
df_train['propertyType'] = df_train['propertyType'].fillna('Purpose Built Flat')
df_test['propertyType'] = df_test['propertyType'].fillna('Purpose Built Flat')

# %%
df_train['currentEnergyRating'].value_counts()
# Out:
# currentEnergyRating
# D    87925
# C    78356
# B    20836
# E    20253
# F     1519
# G      436
# A      186
# Name: count, dtype: int64

# %%
df_test['currentEnergyRating'].value_counts()
# Out:
# currentEnergyRating
# D    5829
# C    5596
# B    2037
# E    1374
# F     127
# G      67
# A      20
# Name: count, dtype: int64

# %%
df_test.isna().sum()
# Out:
# outcode                   0
# latitude                  0
# longitude                 0
# bathrooms                 0
# bedrooms                  0
# floorAreaSqM              0
# livingRooms               0
# tenure                    0
# propertyType              0
# currentEnergyRating    1497
# sale_month                0
# sale_year                 0
# rooms_is_missing          0
# area_is_missing           0
# dtype: int64

# %%
df_train['energy_is_missing'] = df_train['currentEnergyRating'].isna().astype(int)

# %%
df_train['currentEnergyRating'] = df_train['currentEnergyRating'].fillna('D')

# %%
rating_dict = {'A': 7, 'B': 6, 'C': 5, 'D': 4, 'E': 3, 'F': 2, 'G': 1}

# %%
df_train['currentEnergyRating'] = df_train['currentEnergyRating'].map(rating_dict)

# %%
df_test['energy_is_missing'] = df_test['currentEnergyRating'].isna().astype(int)
df_test['currentEnergyRating'] = df_test['currentEnergyRating'].fillna('D')
df_test['currentEnergyRating'] = df_test['currentEnergyRating'].map(rating_dict)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266325 entries, 0 to 266324
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   outcode              266325 non-null  object
#  1   latitude             266325 non-null  float64
#  2   longitude            266325 non-null  float64
#  3   bathrooms            266325 non-null  float64
#  4   bedrooms             266325 non-null  float64
#  5   floorAreaSqM         266325 non-null  float64
#  6   livingRooms          266325 non-null  float64
#  7   tenure               266325 non-null  object
#  8   propertyType         266325 non-null  object
#  9   currentEnergyRating  266325 non-null  int64
#  10  sale_month           266325 non-null  int64
#  11  sale_year            266325 non-null  int64
#  12  price                266325 non-null  int64
#  13  rooms_is_missing     266325 non-null  int64
#  14  area_is_missing      266325 non-null  int64
#  15  energy_is_missing    266325 non-null  int64
# dtypes: float64(6), int64(7), object(3)
# memory usage: 32.5+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16547 entries, 0 to 16546
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   outcode              16547 non-null  object
#  1   latitude             16547 non-null  float64
#  2   longitude            16547 non-null  float64
#  3   bathrooms            16547 non-null  float64
#  4   bedrooms             16547 non-null  float64
#  5   floorAreaSqM         16547 non-null  float64
#  6   livingRooms          16547 non-null  float64
#  7   tenure               16547 non-null  object
#  8   propertyType         16547 non-null  object
#  9   currentEnergyRating  16547 non-null  int64
#  10  sale_month           16547 non-null  int64
#  11  sale_year            16547 non-null  int64
#  12  rooms_is_missing     16547 non-null  int64
#  13  area_is_missing      16547 non-null  int64
#  14  energy_is_missing    16547 non-null  int64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 1.9+ MB

# %%
df_train['outcode'].value_counts()
# Out:
# outcode
# SE18    4444
# SW2     4440
# N16     4163
# SW4     4102
# SW16    4006
#         ...
# EC3V      17
# EC2R       7
# EC2V       7
# W1C        3
# EC3M       2
# Name: count, Length: 167, dtype: int64

# %%
df_train = pd.get_dummies(df_train, columns=['outcode', 'tenure', 'propertyType'], drop_first=True, dtype=int)
df_test = pd.get_dummies(df_test, columns=['outcode', 'tenure', 'propertyType'], drop_first=True, dtype=int)

# %%
df_train, df_test = df_train.align(df_test, join='left', axis=1, fill_value=0)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import SGDRegressor

# %%
print(df_train.columns.tolist())
# Out:
# ['latitude', 'longitude', 'bathrooms', 'bedrooms', 'floorAreaSqM', 'livingRooms', 'currentEnergyRating', 'sale_month', 'sale_year', 'price', 'rooms_is_missing', 'area_is_missing', 'energy_is_missing', 'outcode_E10', 'outcode_E11', 'outcode_E12', 'outcode_E13', 'outcode_E14', 'outcode_E15', 'outcode_E16', 'outcode_E17', 'outcode_E18', 'outcode_E1W', 'outcode_E2', 'outcode_E3', 'outcode_E4', 'outcode_E5', 'outcode_E6', 'outcode_E7', 'outcode_E8', 'outcode_E9', 'outcode_EC1A', 'outcode_EC1M', 'outcode_EC1N', 'outcode_EC1R', 'outcode_EC1V', 'outcode_EC1Y', 'outcode_EC2A', 'outcode_EC2M', 'outcode_EC2R', 'outcode_EC2V', 'outcode_EC2Y', 'outcode_EC3A', 'outcode_EC3M', 'outcode_EC3N', 'outcode_EC3R', 'outcode_EC3V', 'outcode_EC4A', 'outcode_EC4M', 'outcode_EC4R', 'outcode_EC4V', 'outcode_EC4Y', 'outcode_N1', 'outcode_N10', 'outcode_N11', 'outcode_N12', 'outcode_N13', 'outcode_N14', 'outcode_N15', 'outcode_N16', 'outcode_N17', 'outcode_N18', 'outcode_N19', 'outcode_N2', 'outcode_N20', 'outcode_N21', 'outcode_N22', 'outcode_N3', 'outcode_N4', 'outcode_N5', 'outcode_N6', 'outcode_N7', 'outcode_N8', 'outcode_N9', 'outcode_NW1', 'outcode_NW10', 'outcode_NW11', 'outcode_NW2', 'outcode_NW3', 'outcode_NW4', 'outcode_NW5', 'outcode_NW6', 'outcode_NW7', 'outcode_NW8', 'outcode_NW9', 'outcode_SE1', 'outcode_SE10', 'outcode_SE11', 'outcode_SE12', 'outcode_SE13', 'outcode_SE14', 'outcode_SE15', 'outcode_SE16', 'outcode_SE17', 'outcode_SE18', 'outcode_SE19', 'outcode_SE2', 'outcode_SE20', 'outcode_SE21', 'outcode_SE22', 'outcode_SE23', 'outcode_SE24', 'outcode_SE25', 'outcode_SE26', 'outcode_SE27', 'outcode_SE28', 'outcode_SE3', 'outcode_SE4', 'outcode_SE5', 'outcode_SE6', 'outcode_SE7', 'outcode_SE8', 'outcode_SE9', 'outcode_SW10', 'outcode_SW11', 'outcode_SW12', 'outcode_SW13', 'outcode_SW14', 'outcode_SW15', 'outcode_SW16', 'outcode_SW17', 'outcode_SW18', 'outcode_SW19', 'outcode_SW1A', 'outcode_SW1E', 'outcode_SW1H', 'outcode_SW1P', 'outcode_SW1V', 'outcode_SW1W', 'outcode_SW1X', 'outcode_SW1Y', 'outcode_SW2', 'outcode_SW20', 'outcode_SW3', 'outcode_SW4', 'outcode_SW5', 'outcode_SW6', 'outcode_SW7', 'outcode_SW8', 'outcode_SW9', 'outcode_W10', 'outcode_W11', 'outcode_W12', 'outcode_W13', 'outcode_W14', 'outcode_W1B', 'outcode_W1C', 'outcode_W1D', 'outcode_W1F', 'outcode_W1G', 'outcode_W1H', 'outcode_W1J', 'outcode_W1K', 'outcode_W1S', 'outcode_W1T', 'outcode_W1U', 'outcode_W1W', 'outcode_W2', 'outcode_W3', 'outcode_W4', 'outcode_W5', 'outcode_W6', 'outcode_W7', 'outcode_W8', 'outcode_W9', 'outcode_WC1A', 'outcode_WC1B', 'outcode_WC1E', 'outcode_WC1H', 'outcode_WC1N', 'outcode_WC1R', 'outcode_WC1V', 'outcode_WC1X', 'outcode_WC2A', 'outcode_WC2B', 'outcode_WC2E', 'outcode_WC2H', 'outcode_WC2N', 'outcode_WC2R', 'tenure_Freehold', 'tenure_Leasehold', 'tenure_Shared', 'propertyType_Converted Flat', 'propertyType_Detached Bungalow', 'propertyType_Detached House', 'propertyType_Detached Property', 'propertyType_End Terrace Bungalow', 'propertyType_End Terrace House', 'propertyType_End Terrace Property', 'propertyType_Flat/Maisonette', 'propertyType_Mid Terrace Bungalow', 'propertyType_Mid Terrace House', 'propertyType_Mid Terrace Property', 'propertyType_Purpose Built Flat', 'propertyType_Semi-Detached Bungalow', 'propertyType_Semi-Detached House', 'propertyType_Semi-Detached Property', 'propertyType_Terrace Property', 'propertyType_Terraced', 'propertyType_Terraced Bungalow']

# %%
print(df_test.columns.tolist())
# Out:
# ['latitude', 'longitude', 'bathrooms', 'bedrooms', 'floorAreaSqM', 'livingRooms', 'currentEnergyRating', 'sale_month', 'sale_year', 'price', 'rooms_is_missing', 'area_is_missing', 'energy_is_missing', 'outcode_E10', 'outcode_E11', 'outcode_E12', 'outcode_E13', 'outcode_E14', 'outcode_E15', 'outcode_E16', 'outcode_E17', 'outcode_E18', 'outcode_E1W', 'outcode_E2', 'outcode_E3', 'outcode_E4', 'outcode_E5', 'outcode_E6', 'outcode_E7', 'outcode_E8', 'outcode_E9', 'outcode_EC1A', 'outcode_EC1M', 'outcode_EC1N', 'outcode_EC1R', 'outcode_EC1V', 'outcode_EC1Y', 'outcode_EC2A', 'outcode_EC2M', 'outcode_EC2R', 'outcode_EC2V', 'outcode_EC2Y', 'outcode_EC3A', 'outcode_EC3M', 'outcode_EC3N', 'outcode_EC3R', 'outcode_EC3V', 'outcode_EC4A', 'outcode_EC4M', 'outcode_EC4R', 'outcode_EC4V', 'outcode_EC4Y', 'outcode_N1', 'outcode_N10', 'outcode_N11', 'outcode_N12', 'outcode_N13', 'outcode_N14', 'outcode_N15', 'outcode_N16', 'outcode_N17', 'outcode_N18', 'outcode_N19', 'outcode_N2', 'outcode_N20', 'outcode_N21', 'outcode_N22', 'outcode_N3', 'outcode_N4', 'outcode_N5', 'outcode_N6', 'outcode_N7', 'outcode_N8', 'outcode_N9', 'outcode_NW1', 'outcode_NW10', 'outcode_NW11', 'outcode_NW2', 'outcode_NW3', 'outcode_NW4', 'outcode_NW5', 'outcode_NW6', 'outcode_NW7', 'outcode_NW8', 'outcode_NW9', 'outcode_SE1', 'outcode_SE10', 'outcode_SE11', 'outcode_SE12', 'outcode_SE13', 'outcode_SE14', 'outcode_SE15', 'outcode_SE16', 'outcode_SE17', 'outcode_SE18', 'outcode_SE19', 'outcode_SE2', 'outcode_SE20', 'outcode_SE21', 'outcode_SE22', 'outcode_SE23', 'outcode_SE24', 'outcode_SE25', 'outcode_SE26', 'outcode_SE27', 'outcode_SE28', 'outcode_SE3', 'outcode_SE4', 'outcode_SE5', 'outcode_SE6', 'outcode_SE7', 'outcode_SE8', 'outcode_SE9', 'outcode_SW10', 'outcode_SW11', 'outcode_SW12', 'outcode_SW13', 'outcode_SW14', 'outcode_SW15', 'outcode_SW16', 'outcode_SW17', 'outcode_SW18', 'outcode_SW19', 'outcode_SW1A', 'outcode_SW1E', 'outcode_SW1H', 'outcode_SW1P', 'outcode_SW1V', 'outcode_SW1W', 'outcode_SW1X', 'outcode_SW1Y', 'outcode_SW2', 'outcode_SW20', 'outcode_SW3', 'outcode_SW4', 'outcode_SW5', 'outcode_SW6', 'outcode_SW7', 'outcode_SW8', 'outcode_SW9', 'outcode_W10', 'outcode_W11', 'outcode_W12', 'outcode_W13', 'outcode_W14', 'outcode_W1B', 'outcode_W1C', 'outcode_W1D', 'outcode_W1F', 'outcode_W1G', 'outcode_W1H', 'outcode_W1J', 'outcode_W1K', 'outcode_W1S', 'outcode_W1T', 'outcode_W1U', 'outcode_W1W', 'outcode_W2', 'outcode_W3', 'outcode_W4', 'outcode_W5', 'outcode_W6', 'outcode_W7', 'outcode_W8', 'outcode_W9', 'outcode_WC1A', 'outcode_WC1B', 'outcode_WC1E', 'outcode_WC1H', 'outcode_WC1N', 'outcode_WC1R', 'outcode_WC1V', 'outcode_WC1X', 'outcode_WC2A', 'outcode_WC2B', 'outcode_WC2E', 'outcode_WC2H', 'outcode_WC2N', 'outcode_WC2R', 'tenure_Freehold', 'tenure_Leasehold', 'tenure_Shared', 'propertyType_Converted Flat', 'propertyType_Detached Bungalow', 'propertyType_Detached House', 'propertyType_Detached Property', 'propertyType_End Terrace Bungalow', 'propertyType_End Terrace House', 'propertyType_End Terrace Property', 'propertyType_Flat/Maisonette', 'propertyType_Mid Terrace Bungalow', 'propertyType_Mid Terrace House', 'propertyType_Mid Terrace Property', 'propertyType_Purpose Built Flat', 'propertyType_Semi-Detached Bungalow', 'propertyType_Semi-Detached House', 'propertyType_Semi-Detached Property', 'propertyType_Terrace Property', 'propertyType_Terraced', 'propertyType_Terraced Bungalow']

# %%
X_train = df_train.drop('price', axis=1)
y_train = df_train['price']
X_test = df_test.copy()

# %%
scaler = RobustScaler()

# %%
model = SGDRegressor()

# %%
pipe = Pipeline([('scaler', scaler), ('model', model)])

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'model__penalty': ['l2', 'l1'],
    'model__alpha': [0.0001, 0.1],
    'model__learning_rate': ['invscaling', 'adaptive']
}

# %%
final_model = GridSearchCV(pipe, param_grid, cv=3, verbose=2)

# %%
final_model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV] END model__alpha=0.0001, model__learning_rate=invscaling, model__penalty=l2; total time=  12.1s
# [CV] END model__alpha=0.0001, model__learning_rate=invscaling, model__penalty=l2; total time=   8.2s
# [CV] END model__alpha=0.0001, model__learning_rate=invscaling, model__penalty=l2; total time=  11.0s
# [CV] END model__alpha=0.0001, model__learning_rate=invscaling, model__penalty=l1; total time=  20.1s
# [CV] END model__alpha=0.0001, model__learning_rate=invscaling, model__penalty=l1; total time=  11.3s
# [CV] END model__alpha=0.0001, model__learning_rate=invscaling, model__penalty=l1; total time=  17.4s
# [CV] END model__alpha=0.0001, model__learning_rate=adaptive, model__penalty=l2; total time=  16.1s
# [CV] END model__alpha=0.0001, model__learning_rate=adaptive, model__penalty=l2; total time=  24.2s
# [CV] END model__alpha=0.0001, model__learning_rate=adaptive, model__penalty=l2; total time=  17.9s
# [CV] END model__alpha=0.0001, model__learning_rate=adaptive, model__penalty=l1; total time=  26.9s
# [CV] END model__alpha=0.0001, model__learning_rate=adaptive, model__penalty=l1; total time=  35.5s
# [CV] END model__alpha=0.0001, model__learning_rate=adaptive, model__penalty=l1; total time=  32.3s
# [CV] END model__alpha=0.1, model__learning_rate=invscaling, model__penalty=l2; total time=   5.1s
# [CV] END model__alpha=0.1, model__learning_rate=invscaling, model__penalty=l2; total time=   6.9s
# [CV] END model__alpha=0.1, model__learning_rate=invscaling, model__penalty=l2; total time=   4.3s
# [CV] END model__alpha=0.1, model__learning_rate=invscaling, model__penalty=l1; total time=  14.5s
# [CV] END model__alpha=0.1, model__learning_rate=invscaling, model__penalty=l1; total time=  13.9s
# [CV] END model__alpha=0.1, model__learning_rate=invscaling, model__penalty=l1; total time=  20.8s
# [CV] END model__alpha=0.1, model__learning_rate=adaptive, model__penalty=l2; total time=   9.8s
# [CV] END model__alpha=0.1, model__learning_rate=adaptive, model__penalty=l2; total time=  11.2s
# [CV] END model__alpha=0.1, model__learning_rate=adaptive, model__penalty=l2; total time=  17.6s
# [CV] END model__alpha=0.1, model__learning_rate=adaptive, model__penalty=l1; total time=  29.5s
# [CV] END model__alpha=0.1, model__learning_rate=adaptive, model__penalty=l1; total time=  28.3s
# [CV] END model__alpha=0.1, model__learning_rate=adaptive, model__penalty=l1; total time=  26.8s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scaler', RobustScaler()),
#                                        ('model', SGDRegressor())]),
#              param_grid={'model__alpha': [0.0001, 0.1],
#                          'model__learning_rate': ['invscaling', 'adaptive'],
#                          'model__penalty': ['l2', 'l1']},
#              verbose=2)

# %%
X_test = X_test.drop('price', axis=1)

# %%
y_pred = final_model.predict(X_test)

# %%
df_sub['price'] = y_pred

# %%
df_sub
# Out:
#            ID          price
# 0      266325  528006.899232
# 1      266326  425993.478509
# 2      266327  513225.985540
# 3      266328  592805.565502
# 4      266329  739181.331743
# ...       ...            ...
# 16542  282867  225561.381469
# 16543  282868  325831.112022
# 16544  282869  544431.568378
# 16545  282870  821101.680636
# 16546  282871  346474.722065
#
# [16547 rows x 2 columns]

# %%
df_sub.to_csv('sub.csv', index=False, index_label = False)
